# %%
import json 
import numpy as np 
from pathlib import Path
from sentence_transformers import SentenceTransformer

# %%
records_path = Path("data/records/hetionet_cancer_mvp_records_v3.json")

with open(records_path, "r") as f:
    records = json.load(f)

print("Loaded records:", len(records))
print("Example keys:", records[0].keys())
print("Example text:", records[0]["search_text"][:300])
# Out:
# Loaded records: 5367
# Example keys: dict_keys(['id', 'entity_type', 'identifier', 'name', 'search_text', 'metadata'])
# Example text: Gene: SLC2A3. Description: solute carrier family 2 (facilitated glucose transporter), member 3. Associated diseases: germ cell cancer (associates); melanoma (upregulates).

# %%
model_name = "sentence-transformers/all-MiniLM-L6-v2"
model = SentenceTransformer(model_name)

print("Model loaded:", model_name)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Model loaded: sentence-transformers/all-MiniLM-L6-v2

# %%
texts = [r["search_text"] for r in records]
ids = [r["id"] for r in records]

print("Num texts:", len(texts))
print("First text sample:\n", texts[0][:500])
# Out:
# Num texts: 5367
# First text sample:
#  Gene: SLC2A3. Description: solute carrier family 2 (facilitated glucose transporter), member 3. Associated diseases: germ cell cancer (associates); melanoma (upregulates).

# %%
embeddings = model.encode(
    texts,
    batch_size=64,
    show_progress_bar=True,
    convert_to_numpy=True,
    normalize_embeddings=True
)

print("Embeddings shape:", embeddings.shape)
print("dtype:", embeddings.dtype)
# Out:
# Batches:   0%|          | 0/84 [00:00<?, ?it/s]
# Embeddings shape: (5367, 384)
# dtype: float32

# %%
out_dir = Path("data/embeddings/vector_index")
out_dir.mkdir(exist_ok=True)

np.save(out_dir / "hetionet_mvp_embeddings.npy", embeddings)

with open(out_dir / "hetionet_mvp_records.json", "w") as f:
    json.dump(records, f, indent=2)

print("Saved embeddings to:", out_dir / "hetionet_mvp_embeddings.npy")
print("Saved records to:", out_dir / "hetionet_mvp_records.json")
# Out:
# Saved embeddings to: /Users/shaunak/Documents/Hacklytics2026/vector_index/hetionet_mvp_embeddings.npy
# Saved records to: /Users/shaunak/Documents/Hacklytics2026/vector_index/hetionet_mvp_records.json

# %% [markdown]
# # Local semantic search test

# %%
import numpy as np

def semantic_search(
    query,
    model,
    embeddings,
    records,
    top_k=5,
    kind_filter=None,
    must_contain=None, 
):
    """
    kind_filter: None or one of {"Gene", "Disease", "Compound"}
    must_contain: optional string that must appear in search_text (case-insensitive)
    """

    # 1) Embed query
    q_emb = model.encode(
        [query],
        convert_to_numpy=True,
        normalize_embeddings=True,
        show_progress_bar=False
    )[0]

    # 2) Cosine similarity (works because embeddings are normalized)
    scores = embeddings @ q_emb

    # 3) Start with all candidates
    candidate_idxs = np.arange(len(records))

    # 4) Applying entity-type filter
    if kind_filter is not None:
        candidate_idxs = np.array([
            i for i, r in enumerate(records)
            if r.get("entity_type") == kind_filter
        ])

    # 5) Applying keyword constraint (NEW)
    if must_contain is not None:
        token = must_contain.lower().strip()
        candidate_idxs = np.array([
            i for i in candidate_idxs
            if token in (records[i].get("search_text", "").lower())
        ])

    # If nothing survives filters
    if len(candidate_idxs) == 0:
        return []

    # 6) Top-k among candidates
    candidate_scores = scores[candidate_idxs]
    k = min(top_k, len(candidate_idxs))
    top_local = np.argsort(-candidate_scores)[:k]
    top_idxs = candidate_idxs[top_local]

    # 7) Formatting results
    results = []
    for i in top_idxs:
        r = records[i]
        results.append({
            "score": float(scores[i]),
            "entity_type": r.get("entity_type"),
            "id": r.get("id"),
            "identifier": r.get("identifier"),
            "name": r.get("name"),
            "search_text": r.get("search_text"),
            "metadata": r.get("metadata", {})
        })

    return results

# %%
# Using some sample queries

queries = [
    ("genes associated with lung cancer", "Gene"),
    ("compounds used for breast cancer", "Compound"),
    ("diseases associated with TP53", "Disease"),
    ("cancer drugs targeting EGFR", "Compound"),
    ("What are the top genes related to cancer?", "Gene"),
]

for q, filt in queries:
    print("\n" + "="*100)
    print("QUERY:", q)
    print("FILTER:", filt)

    hits = semantic_search(q, model, embeddings, records, top_k=5, kind_filter=filt)

    for h in hits:
        print(f"\n[{h['score']:.3f}] {h['entity_type']} | {h['id']} | {h['name']}")
        print(h["search_text"][:300])
# Out:
# ====================================================================================================
# QUERY: genes associated with lung cancer
# FILTER: Gene
#
# [0.710] Gene | Gene::1810 | DR1
# Gene: DR1. Description: down-regulator of transcription 1, TBP-binding (negative cofactor 2). Associated diseases: lung cancer (upregulates).
#
# [0.705] Gene | Gene::25771 | TBC1D22A
# Gene: TBC1D22A. Description: TBC1 domain family, member 22A. Associated diseases: lung cancer (upregulates).
#
# [0.704] Gene | Gene::128602 | C20orf85
# Gene: C20orf85. Description: chromosome 20 open reading frame 85. Associated diseases: lung cancer (associates).
#
# [0.698] Gene | Gene::92689 | FAM114A1
# Gene: FAM114A1. Description: family with sequence similarity 114, member A1. Associated diseases: lung cancer (upregulates).
#
# [0.696] Gene | Gene::118611 | C10orf90
# Gene: C10orf90. Description: chromosome 10 open reading frame 90. Associated diseases: lung cancer (upregulates).
#
# ====================================================================================================
# QUERY: compounds used for breast cancer
# FILTER: Compound
#
# [0.613] Compound | Compound::DB00481 | Raloxifene
# Compound: Raloxifene. Treats or relates to diseases: breast cancer (treats).
#
# [0.606] Compound | Compound::DB00286 | Conjugated Estrogens
# Compound: Conjugated Estrogens. Treats or relates to diseases: breast cancer (palliates); prostate cancer (treats).
#
# [0.601] Compound | Compound::DB00624 | Testosterone
# Compound: Testosterone. Treats or relates to diseases: breast cancer (palliates).
#
# [0.594] Compound | Compound::DB01259 | Lapatinib
# Compound: Lapatinib. Treats or relates to diseases: breast cancer (treats).
#
# [0.592] Compound | Compound::DB08866 | Estradiol valerate/Dienogest
# Compound: Estradiol valerate/Dienogest. Treats or relates to diseases: breast cancer (palliates); prostate cancer (treats).
#
# ====================================================================================================
# QUERY: diseases associated with TP53
# FILTER: Disease
#
# [0.491] Disease | Disease::DOID:5559 | mediastinal cancer
# Disease: mediastinal cancer. Associated genes: PTPN1 (associates). Related diseases: lung cancer (resembles); thymus cancer (resembles); muscle cancer (resembles); testicular cancer (resembles); germ cell cancer (resembles); esophageal cancer (resembles); peripheral nervous system neoplasm (resemble
#
# [0.462] Disease | Disease::DOID:3277 | thymus cancer
# Disease: thymus cancer. Associated genes: MUSK (associates); TP53 (associates); DPYSL5 (associates); AKT1 (associates); TSR1 (associates); CEMP1 (associates); CD99 (associates); KCNA4 (associates); IL2 (associates); CD8A (associates); CYLD (associates); KIT (associates); MAML2 (associates); BAP1 (as
#
# [0.452] Disease | Disease::DOID:11920 | tracheal cancer
# Disease: tracheal cancer. Associated genes: NT5C1B (associates). Related diseases: esophageal cancer (resembles); head and neck cancer (resembles); pharynx cancer (resembles); thyroid cancer (resembles); sarcoma (resembles); uterine fibroid (resembles); salivary gland cancer (resembles); peripheral
#
# [0.451] Disease | Disease::DOID:2596 | larynx cancer
# Disease: larynx cancer. Associated genes: ACOT13 (associates); HPD (associates); TP53 (associates); PDPN (associates); OAF (associates). Related diseases: bone cancer (resembles); head and neck cancer (resembles); esophageal cancer (resembles); muscle cancer (resembles); thyroid cancer (resembles);
#
# [0.434] Disease | Disease::DOID:0060119 | pharynx cancer
# Disease: pharynx cancer. Associated genes: CD6 (associates); MMP8 (associates); TMEM8B (associates); CCND1 (associates); B4GALT5 (associates); CNDP2 (associates); BPIFA1 (associates); EIF2AK1 (associates); CDH1 (associates); CD79A (associates); TP53 (associates); CFAP45 (associates); EGFR (associate
#
# ====================================================================================================
# QUERY: cancer drugs targeting EGFR
# FILTER: Compound
#
# [0.468] Compound | Compound::DB00736 | Esomeprazole
# Compound: Esomeprazole. Treats or relates to diseases: esophageal cancer (palliates); prostate cancer (palliates); kidney cancer (palliates).
#
# [0.467] Compound | Compound::DB00530 | Erlotinib
# Compound: Erlotinib. Treats or relates to diseases: lung cancer (treats); pancreatic cancer (treats); kidney cancer (treats).
#
# [0.447] Compound | Compound::DB00445 | Epirubicin
# Compound: Epirubicin. Treats or relates to diseases: stomach cancer (treats); pancreatic cancer (treats); liver cancer (treats); prostate cancer (treats); thyroid cancer (treats); sarcoma (treats); hematologic cancer (treats); testicular cancer (treats); peripheral nervous system neoplasm (treats);
#
# [0.443] Compound | Compound::DB00958 | Carboplatin
# Compound: Carboplatin. Treats or relates to diseases: breast cancer (treats); uterine cancer (treats); ocular cancer (treats); esophageal cancer (treats); ovarian cancer (treats); testicular cancer (treats); urinary bladder cancer (treats); brain cancer (treats); bone cancer (treats).
#
# [0.443] Compound | Compound::DB01229 | Paclitaxel
# Compound: Paclitaxel. Treats or relates to diseases: lung cancer (treats); kidney cancer (treats); breast cancer (treats); ovarian cancer (treats).
#
# ====================================================================================================
# QUERY: What are the top genes related to cancer?
# FILTER: Gene
#
# [0.745] Gene | Gene::7150 | TOP1
# Gene: TOP1. Description: topoisomerase (DNA) I. Associated diseases: lung cancer (associates); hematologic cancer (associates); ovarian cancer (associates); colon cancer (associates); melanoma (upregulates).
#
# [0.674] Gene | Gene::595 | CCND1
# Gene: CCND1. Description: cyclin D1. Associated diseases: esophageal cancer (associates); ocular cancer (associates); sarcoma (associates); breast cancer (associates); colon cancer (upregulates); salivary gland cancer (associates); thyroid cancer (associates); pharynx cancer (associates); lung cance
#
# [0.663] Gene | Gene::9215 | LARGE
# Gene: LARGE. Description: like-glycosyltransferase. Associated diseases: lung cancer (upregulates); liver cancer (associates).
#
# [0.661] Gene | Gene::7153 | TOP2A
# Gene: TOP2A. Description: topoisomerase (DNA) II alpha 170kDa. Associated diseases: hematologic cancer (associates); breast cancer (associates); adrenal gland cancer (associates); malignant glioma (associates); salivary gland cancer (associates); breast cancer (upregulates); prostate cancer (associa
#
# [0.651] Gene | Gene::1474 | CST6
# Gene: CST6. Description: cystatin E/M. Associated diseases: breast cancer (associates); melanoma (associates); prostate cancer (associates); lung cancer (associates).

# %%
print(records[0].keys())
print(records[0])
# Out:
# dict_keys(['id', 'entity_type', 'identifier', 'name', 'search_text', 'metadata'])
# {'id': 'Gene::9055', 'entity_type': 'Gene', 'identifier': 9055, 'name': 'PRC1', 'search_text': 'Gene: PRC1. Description: protein regulator of cytokinesis 1. Related diseases: breast cancer (upregulates); pancreatic cancer (upregulates); breast cancer (associates).', 'metadata': {'description': 'protein regulator of cytokinesis 1', 'source': 'Entrez Gene', 'license': 'CC0 1.0', 'url': 'http://identifiers.org/ncbigene/9055', 'chromosome': '15'}}

# %%
hits = semantic_search("compounds used for breast cancer", model, embeddings, records, top_k=20, kind_filter="Compound")
print([h["entity_type"] for h in hits])
# Out:
# ['Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound', 'Compound']

# %%
# Basic checks for records
print(type(records))
print("num records:", len(records))

# Show keys in first record
print("first record keys:", records[0].keys())

# Show first record (truncated view)
for k, v in records[0].items():
    if isinstance(v, str):
        print(f"{k}: {v[:200]}")
    else:
        print(f"{k}: {v}")
# Out:
# <class 'list'>
# num records: 5367
# first record keys: dict_keys(['id', 'entity_type', 'identifier', 'name', 'search_text', 'metadata'])
# id: Gene::6515
# entity_type: Gene
# identifier: 6515
# name: SLC2A3
# search_text: Gene: SLC2A3. Description: solute carrier family 2 (facilitated glucose transporter), member 3. Associated diseases: germ cell cancer (associates); melanoma (upregulates).
# metadata: {'description': 'solute carrier family 2 (facilitated glucose transporter), member 3', 'source': 'Entrez Gene', 'license': 'CC0 1.0', 'url': 'http://identifiers.org/ncbigene/6515', 'chromosome': '12'}

# %%
required = {"id", "entity_type", "identifier", "name", "search_text", "metadata"}

missing_counts = {k: 0 for k in required}
bad_records = []

for i, r in enumerate(records):
    missing = required - set(r.keys())
    if missing:
        bad_records.append((i, missing))
        for m in missing:
            missing_counts[m] += 1

print("Missing key counts:", missing_counts)
print("Number of bad records:", len(bad_records))

# Checking first few problematic records if any
print("Sample bad records:", bad_records[:5])
# Out:
# Missing key counts: {'identifier': 0, 'search_text': 0, 'entity_type': 0, 'name': 0, 'metadata': 0, 'id': 0}
# Number of bad records: 0
# Sample bad records: []

# %%
print(type(embeddings))
print("embeddings shape:", embeddings.shape)
print("embeddings dtype:", embeddings.dtype)

print("len(records):", len(records))
print("embedding rows:", embeddings.shape[0])
print("rows match:", len(records) == embeddings.shape[0])
# Out:
# <class 'numpy.ndarray'>
# embeddings shape: (5367, 384)
# embeddings dtype: float32
# len(records): 5367
# embedding rows: 5367
# rows match: True
